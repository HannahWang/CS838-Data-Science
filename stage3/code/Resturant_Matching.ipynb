# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook uses Magellan, an Entity Matching (EM) tool developed in University of Wisconsin - Madison, to match resturants from Yelp (Dataset A) and Tridadvisor (Dataset B). Each dataset consists of information of 3000+ resturants in Los Angeles.
#
# First, import *py_entitymatching* and other libraries.

# %%
import py_entitymatching as em
import pandas as pd
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Read input tables

# %% [markdown]
# Load csv file as dataframes and set the key attribute in the dataframe

# %%
A = em.read_csv_metadata('../data/A.csv', key='id')
B = em.read_csv_metadata('../data/B.csv', key='id')
# Out:
# No handlers could be found for logger "py_entitymatching.io.parsers"

# %%
print('Number of tuples in A: ' + str(len(A)))
print('Number of tuples in B: ' + str(len(B)))
print('Number of tuples in A X B: ' + str(len(A) * len(B)))
# Out:
# Number of tuples in A: 3188
# Number of tuples in B: 3120
# Number of tuples in A X B: 9946560

# %%
A.head(4)
# Out:
#    id                                 name category_1  category_2  \
# 0  a1  Hae Jang Chon Korean BBQ Restaurant     korean    barbeque
# 1  a2               Kang Ho-dong Baekjeong   barbeque      korean
# 2  a3                        Road To Seoul     korean    barbeque
# 3  a4                             Langer's      delis  sandwiches
#
#               address         city  zipcode         phone  price  rating  \
# 0       3821 W 6th St  Los Angeles  90020.0  2.133899e+09    2.0     4.0
# 1       3465 W 6th St  Los Angeles  90020.0  2.133850e+09    2.0     4.5
# 2  1230 S Western Ave  Los Angeles  90006.0  3.237319e+09    2.0     4.0
# 3   704 S Alvarado St  Los Angeles  90057.0  2.134838e+09    2.0     4.5
#
#         ...         hours_tue_open  hours_tue_close  hours_wed_open  \
# 0       ...                 1100.0            200.0          1100.0
# 1       ...                 1130.0            130.0          1130.0
# 2       ...                 1100.0           2400.0          1100.0
# 3       ...                  800.0           1600.0           800.0
#
#    hours_wed_close  hours_thu_open  hours_thu_close  hours_fri_open  \
# 0            200.0          1100.0            200.0          1100.0
# 1            130.0          1130.0            130.0          1130.0
# 2           2400.0          1100.0            100.0          1100.0
# 3           1600.0           800.0           1600.0           800.0
#
#    hours_fir_close  hours_sat_open  hours_sat_close
# 0            200.0          1100.0            200.0
# 1            130.0          1130.0            130.0
# 2            100.0          1100.0           2300.0
# 3           1600.0             NaN              NaN
#
# [4 rows x 25 columns]

# %%
B.head(4)
# Out:
#    id                               name category_1           category_2  \
# 0  b1                         Providence    Seafood  Vegetarian Friendly
# 1  b2               Raffaello Ristorante    Italian  Vegetarian Friendly
# 2  b3  Brent's Delicatessen & Restaurant   American         Delicatessen
# 3  b4                    Tocaya Organica    Mexican                Latin
#
#                address         city  zipcode         phone  price  rating  \
# 0     5955 Melrose Ave  Los Angeles  90038.0  3.238378e+09    4.0     4.5
# 1    400 S Pacific Ave  Los Angeles  90731.0  3.105141e+09    2.5     4.5
# 2   19565 Parthenia St  Los Angeles  91324.0  8.188866e+09    2.5     4.5
# 3  1715 Pacific Avenue  Los Angeles      NaN  4.247449e+09    1.0     4.5
#
#         ...         hours_tue_open  hours_tue_close  hours_wed_open  \
# 0       ...                 1800.0           2200.0          1800.0
# 1       ...                 1100.0           1400.0          1100.0
# 2       ...                  600.0           2100.0           600.0
# 3       ...                    NaN              NaN             NaN
#
#    hours_wed_close  hours_thu_open  hours_thu_close  hours_fri_open  \
# 0           2200.0          1800.0           2200.0          1800.0
# 1           1400.0          1100.0           1400.0          1100.0
# 2           2100.0           600.0           2100.0           600.0
# 3              NaN             NaN              NaN             NaN
#
#    hours_fri_close  hours_sat_open  hours_sat_close
# 0           2200.0          1730.0           2200.0
# 1           1400.0          1500.0           2145.0
# 2           2100.0           600.0           2100.0
# 3              NaN             NaN              NaN
#
# [4 rows x 25 columns]

# %% [markdown]
# Since both tables are small, downsampling is not performed.

# %% [markdown]
# # Block tables to get candidate set

# %% [markdown]
# ## First attempt
#
# Blocker 1: Matching resturants should be in the same city
#
# Since all the resturants are in the Los Angeles area, blocker 1 still results in a large number of candidate pairs.

# %%
# Create attribute equivalence blocker
ab1 = em.AttrEquivalenceBlocker()

# Block using city attribute
C1 = ab1.block_tables(A, B, 'city', 'city',
                     l_output_attrs = ['name', 'address', 'city', 'zipcode', 'phone'],
                     r_output_attrs = ['name', 'address', 'city', 'zipcode', 'phone'])

len(C1)
# Out:
# 3435309

# %% [markdown]
# Blocker 2: Matching resturants should be within the same zipcode
#
# This step reduces the preivous candidate set by a factor of 10

# %%
# Create attribute equivalence blocker
ab2 = em.AttrEquivalenceBlocker()

# Block using zipcod attribute
C2 = ab2.block_candset(C1, 'zipcode', 'zipcode', allow_missing = True, 
                      show_progress = False)

len(C2)
# Out:
# 279897

# %% [markdown]
# Blocker 3: matching resturants should use the same phone number
#
# This blocker reduces the candiate set by a factor of 5

# %%
# Create attribute equivalence blocker
ab3 = em.AttrEquivalenceBlocker()

# Block using phone number
C3 = ab3.block_candset(C2, 'phone', 'phone', allow_missing = True,
                      show_progress = False)

len(C3)
# Out:
# 51576

# %% [markdown]
# Blocker 4: matching resturants should share some common words in street adress
#
# In this step, stopwords needs to be updated to include common words in address, such as "Street", "st", "Avenue", "Ave", "Boulevard", "Blvd", "Drive", "Dr", "Road", "Rd"
#
# This block reduces the candidate set by a factor of 5

# %%
# Create overlap blocker
op1 = em.OverlapBlocker()

# Update stopwords
addr_stopwords = ['street','st','avenue','ave','boulevard','blvd',
                     'drive','dr','road','rd','s','n','e','w']
op1.stop_words.extend(addr_stopwords)

op1.stop_words
# Out:
# ['a',
#  'an',
#  'and',
#  'are',
#  'as',
#  'at',
#  'be',
#  'by',
#  'for',
#  'from',
#  'has',
#  'he',
#  'in',
#  'is',
#  'it',
#  'its',
#  'on',
#  'that',
#  'the',
#  'to',
#  'was',
#  'were',
#  'will',
#  'with',
#  'street',
#  'st',
#  'avenue',
#  'ave',
#  'boulevard',
#  'blvd',
#  'drive',
#  'dr',
#  'road',
#  'rd',
#  's',
#  'n',
#  'e',
#  'w']

# %%
# Block using address
C4 = op1.block_candset(C3, 'address', 'address', word_level = True, overlap_size = 1,
                      rem_stop_words = True, show_progress = False, allow_missing = True)

len(C4)
# Out:
# 3885

# %% [markdown]
# Blocker 5: matching resturants should share common tokens in name
#
# This step reduces the candidate set by a factor of 10

# %%
# Create overlap blocker
op2 = em.OverlapBlocker()

# Block using name
C5 = op2.block_candset(C4, 'name', 'name', word_level = False, q_val = 3,
                      overlap_size = 2, show_progress = False, allow_missing = True)

len(C5)
# Out:
# 956

# %%
C5.head(10)
# Out:
#          _id ltable_id rtable_id                          ltable_name  \
# 133      133        a1      b162  Hae Jang Chon Korean BBQ Restaurant
# 2736    2736        a2      b268               Kang Ho-dong Baekjeong
# 4121    4121        a2     b1987               Kang Ho-dong Baekjeong
# 5613    5613        a3      b710                        Road To Seoul
# 7584    7584        a4        b7                             Langer's
# 10415  10415        a5      b392                EMC Seafood & Raw Bar
# 12803  12803        a6      b223         Soowon Galbi KBBQ Restaurant
# 15462  15462        a7      b385                           Beer Belly
# 17979  17979        a8      b372                       BCD Tofu House
# 20954  20954        a9      b939                   Slurpin' Ramen Bar
#
#            ltable_address  ltable_city  ltable_zipcode  ltable_phone  \
# 133         3821 W 6th St  Los Angeles         90020.0  2.133899e+09
# 2736        3465 W 6th St  Los Angeles         90020.0  2.133850e+09
# 4121        3465 W 6th St  Los Angeles         90020.0  2.133850e+09
# 5613   1230 S Western Ave  Los Angeles         90006.0  3.237319e+09
# 7584    704 S Alvarado St  Los Angeles         90057.0  2.134838e+09
# 10415       3500 W 6th St  Los Angeles         90020.0  2.133520e+09
# 12803   856 S Vermont Ave  Los Angeles         90005.0  2.133659e+09
# 15462   532 S Western Ave  Los Angeles         90020.0  2.133872e+09
# 17979  3575 Wilshire Blvd  Los Angeles         90010.0  2.133827e+09
# 20954       3500 W 8th St  Los Angeles         90005.0  2.133889e+09
#
#                                rtable_name        rtable_address  rtable_city  \
# 133    Hae Jang Chon Korean BBQ Restaurant         3821 W 6th St  Los Angeles
# 2736                 Kang Hodong Baekjeong         3465 W 6th St  Los Angeles
# 4121                 KangHoDong Baek Jeong  3465 W 6th St Ste 20  Los Angeles
# 5613                         Road to Seoul    1230 S Western Ave  Los Angeles
# 7584                              Langer's     704 S Alvarado St  Los Angeles
# 10415              EMC Seafood and Raw Bar         3500 W 6th St  Los Angeles
# 12803                         Soowon Galbi     856 S Vermont Ave  Los Angeles
# 15462                           Beer Belly     532 S Western Ave  Los Angeles
# 17979                       BCD Tofu House    3575 Wilshire Blvd  Los Angeles
# 20954                   Slurpin' Ramen Bar         3500 W 8th St  Los Angeles
#
#        rtable_zipcode  rtable_phone
# 133           90020.0  2.133899e+09
# 2736          90020.0  2.133850e+09
# 4121          90020.0  2.133850e+09
# 5613          90006.0  3.237319e+09
# 7584          90057.0  2.134838e+09
# 10415         90020.0  2.133520e+09
# 12803         90005.0  2.133659e+09
# 15462         90020.0  2.133872e+09
# 17979         90010.0  2.133827e+09
# 20954         90005.0  2.133889e+09

# %% [markdown]
# ### Debug Blocker
#
# Make sure that blocker did not drop any potential matches
#
# This step removes the equivalance blocker on city, since the city attributes have different context in the two tables.

# %%
# Debug blocker output
dbg = em.debug_blocker(C5, A, B, output_size = 200)

dbg.head()
# Out:
#    _id ltable_id rtable_id                 ltable_name ltable_category_1  \
# 0    0      a629     b2329  Andre's Italian Restaurant           italian
# 1    1     a2209     b1456                      Tacone    american (new)
# 2    2       a73     b1471        Grand Central Market        food court
# 3    3     a2284     b1649                   Yoshinoya          japanese
# 4    4     a1810      b780       Pitfire Artisan Pizza             pizza
#
#   ltable_category_2        ltable_address      ltable_city  \
# 0             pizza         6332 W 3rd St      Los Angeles
# 1               NaN         330 S Hope St      Los Angeles
# 2               NaN        317 S Broadway      Los Angeles
# 3         fast food    3021 S Figueroa St      Los Angeles
# 4        sandwiches  5211 Lankershim Blvd  North Hollywood
#
#                     rtable_name rtable_category_1 rtable_category_2  \
# 0                    All'Angolo           Italian             Pizza
# 1      California Pizza Kitchen          American             Pizza
# 2  Golden Road at Grand Central               NaN               NaN
# 3                   Chick-fil-A         Fast Food          American
# 4         Pitfire Artisan Pizza             Pizza           Italian
#
#          rtable_address  rtable_city
# 0         4050 W 3rd St  Los Angeles
# 1         330 S Hope St  Los Angeles
# 2        317 S Broadway  Los Angeles
# 3    3758 S Figueroa St  Los Angeles
# 4  5211 Lankershim Blvd  Los Angeles

# %% [markdown]
# The debug results suggest two issues in the original blocker.
#
# 1) the city attribute in Table A has a different schema context from that of table B. In table A (yelp), the city attributes indicates city or particular location (e.g. Hollywook) for some resturants. Therefore, the attribute equivalance blocker based on city needs to be removed.
#
# 2) Equivalance on phone number could be too aggressive. A single resturant could have two different phone numbers, and typos are more often in phone number attribute. Therefore, the blocker on phone number need to be changed to overlap blocker.

# %% [markdown]
# ## Final Blocker
#
#  * attribute equivalance on zipcode
#  * overlap of at least 2 3-gram words in name
#  * overlap of at least 2 3-gram words in address
#  * overlap of at least 4 3-gram words in phone number
#
# The final candidate set includes 1745 tuple pairs.

# %%
# Block using zipcode attribute equivalance
ab3 = em.AttrEquivalenceBlocker()
C6 = ab3.block_tables(A, B, 'zipcode', 'zipcode', allow_missing = True,
                     l_output_attrs = ['name', 'address', 'city', 'zipcode', 'phone'],
                     r_output_attrs = ['name', 'address', 'city', 'zipcode', 'phone'])

len(C6)
# Out:
# 1038989

# %%
# Block using address
op3 = em.OverlapBlocker()
op3.stop_words.extend(addr_stopwords)
C7 = op3.block_candset(C6, 'address', 'address', word_level = True, overlap_size = 1,
                      rem_stop_words = True, show_progress = False, allow_missing = False)

len(C7)
# Out:
# 23390

# %%
# Block using name
op4 = em.OverlapBlocker()
C8 = op4.block_candset(C7, 'name', 'name', word_level = False, q_val = 3,
                      overlap_size = 2, show_progress = False, allow_missing = True)

len(C8)
# Out:
# 2803

# %%
# Block using phone number
op5 = em.OverlapBlocker()
C = op5.block_candset(C8, 'phone', 'phone', word_level = False, q_val = 3,
                      overlap_size = 4, allow_missing = True, show_progress = False)

# %%
len(C)
# Out:
# 1745

# %%
C.head()
# Out:
#     _id ltable_id rtable_id                          ltable_name  \
# 1     1        a1      b162  Hae Jang Chon Korean BBQ Restaurant
# 2     2        a1      b268  Hae Jang Chon Korean BBQ Restaurant
# 10   10        a1     b1987  Hae Jang Chon Korean BBQ Restaurant
# 23   23        a2      b162               Kang Ho-dong Baekjeong
# 24   24        a2      b268               Kang Ho-dong Baekjeong
#
#    ltable_address  ltable_city  ltable_zipcode  ltable_phone  \
# 1   3821 W 6th St  Los Angeles         90020.0  2.133899e+09
# 2   3821 W 6th St  Los Angeles         90020.0  2.133899e+09
# 10  3821 W 6th St  Los Angeles         90020.0  2.133899e+09
# 23  3465 W 6th St  Los Angeles         90020.0  2.133850e+09
# 24  3465 W 6th St  Los Angeles         90020.0  2.133850e+09
#
#                             rtable_name        rtable_address  rtable_city  \
# 1   Hae Jang Chon Korean BBQ Restaurant         3821 W 6th St  Los Angeles
# 2                 Kang Hodong Baekjeong         3465 W 6th St  Los Angeles
# 10                KangHoDong Baek Jeong  3465 W 6th St Ste 20  Los Angeles
# 23  Hae Jang Chon Korean BBQ Restaurant         3821 W 6th St  Los Angeles
# 24                Kang Hodong Baekjeong         3465 W 6th St  Los Angeles
#
#     rtable_zipcode  rtable_phone
# 1          90020.0  2.133899e+09
# 2          90020.0  2.133850e+09
# 10         90020.0  2.133850e+09
# 23         90020.0  2.133899e+09
# 24         90020.0  2.133850e+09

# %%
# Debug blocker output
dbg = em.debug_blocker(C, A, B, output_size = 200)

dbg.head(50)
# Out:
#     _id ltable_id rtable_id                    ltable_name  \
# 0     0      a565     b2179                  TOI On Sunset
# 1     1     a1398     b2097                   Natalee Thai
# 2     2      a354     b2660                 El Gallo Grill
# 3     3      a664      b435                       El Huero
# 4     4       a88      b923                  Orochon Ramen
# 5     5     a2448     b3036                Jimmy's Kitchen
# 6     6     a2425      b278                  Panda Express
# 7     7      a844     b2761                Tottino's Pizza
# 8     8     a1224     b2689         Chipotle Mexican Grill
# 9     9     a2207     b2672                     Dan's Deli
# 10   10      a844     b1254                Tottino's Pizza
# 11   11     a2444     b3036                          Kikka
# 12   12      a354     b2052                 El Gallo Grill
# 13   13     a2433     b3036                      Taco Bell
# 14   14     a2022     b1883         NBC Seafood Restaurant
# 15   15      a122     b2647                    Cafe Creole
# 16   16     a2125     b1649  Chick-fil-A 7th & Fig In-Line
# 17   17     a1141     b2875                  El Pollo Loco
# 18   18      a321      b120                   Moles La Tia
# 19   19      a313      b120          La Azteca Tortilleria
# 20   20      a664     b1124                       El Huero
# 21   21       a87      b636                      Sushi Gen
# 22   22     a1192      b399                    Shake Shack
# 23   23     a1085     b2387                  El Pollo Loco
# 24   24      a165      b636                     Hama Sushi
# 25   25     a2136      b248  Il Tramezzino - Beverly Hills
# 26   26      a354      b120                 El Gallo Grill
# 27   27     a1085      b639                  El Pollo Loco
# 28   28     a2051     b1921                  El Pollo Loco
# 29   29      a322     b2660               Tamales Lilianas
# 30   30      a322     b2052               Tamales Lilianas
# 31   31     a1085     b1921                  El Pollo Loco
# 32   32      a313     b2270          La Azteca Tortilleria
# 33   33      a354     b2270                 El Gallo Grill
# 34   34      a321     b2270                   Moles La Tia
# 35   35     a2119     b2898                      Five Guys
# 36   36     a1035      b742          Mitsuru Sushi & Grill
# 37   37      a145     b1921                  El Pollo Loco
# 38   38     a1192      b892                    Shake Shack
# 39   39      a243     b1430                  2 For 1 Pizza
# 40   40      a547     b1607          Palms Thai Restaurant
# 41   41      a324     b1671                     Thai House
# 42   42     a2290     b1649                         Subway
# 43   43      a685     b1649                      Fatburger
# 44   44      a141     b1430                     Pizza King
# 45   45       a87      b981                      Sushi Gen
# 46   46      a165      b981                     Hama Sushi
# 47   47     a2209     b1456                         Tacone
# 48   48      a547     b1308          Palms Thai Restaurant
# 49   49      a149      b148                    Latitude 33
#
#          ltable_category_1 ltable_category_2  \
# 0                     thai               NaN
# 1                     thai               NaN
# 2                  mexican               NaN
# 3                  mexican         fast food
# 4                    ramen           noodles
# 5             asian fusion               NaN
# 6                  chinese         fast food
# 7                    pizza           italian
# 8                fast food           mexican
# 9                    delis        sandwiches
# 10                   pizza           italian
# 11              sushi bars             ramen
# 12                 mexican               NaN
# 13               fast food               NaN
# 14                 seafood           dim sum
# 15            cajun/creole               NaN
# 16               fast food               NaN
# 17               fast food           mexican
# 18                 mexican               NaN
# 19                 mexican               NaN
# 20                 mexican         fast food
# 21              sushi bars          japanese
# 22  american (traditional)         fast food
# 23                 mexican         fast food
# 24              sushi bars          japanese
# 25                 italian               NaN
# 26                 mexican               NaN
# 27                 mexican         fast food
# 28               fast food           mexican
# 29                 mexican               NaN
# 30                 mexican               NaN
# 31                 mexican         fast food
# 32                 mexican               NaN
# 33                 mexican               NaN
# 34                 mexican               NaN
# 35                 burgers         fast food
# 36                japanese        sushi bars
# 37               fast food           mexican
# 38  american (traditional)         fast food
# 39                   pizza           italian
# 40                 seafood              thai
# 41                    thai           chinese
# 42              sandwiches         fast food
# 43                 burgers         fast food
# 44                   pizza               NaN
# 45              sushi bars          japanese
# 46              sushi bars          japanese
# 47          american (new)               NaN
# 48                 seafood              thai
# 49  american (traditional)               NaN
#
#                        ltable_address    ltable_city  \
# 0              7505 1/2 W Sunset Blvd    Los Angeles
# 1                   10101 Venice Blvd    Los Angeles
# 2           4533 E Cesar E Chavez Ave    Los Angeles
# 3                  3000 S Figueroa St    Los Angeles
# 4        123 Astronaut E S Onizuka St    Los Angeles
# 5                    308 Westwood Plz    Los Angeles
# 6                    308 Westwood Plz    Los Angeles
# 7                  1139 N La Brea Ave      Inglewood
# 8             10250 Santa Monica Blvd    Los Angeles
# 9                     300 S Grand Ave    Los Angeles
# 10                 1139 N La Brea Ave      Inglewood
# 11                   308 Westwood Plz    Los Angeles
# 12          4533 E Cesar E Chavez Ave    Los Angeles
# 13                   308 Westwood Plz    Los Angeles
# 14                404 S Atlantic Blvd  Monterey Park
# 15  3650 W Martin Luther King Jr Blvd    Los Angeles
# 16                  660 S Figueroa St    Los Angeles
# 17                  330 N Alvarado St    Los Angeles
# 18          4619 E Cesar E Chavez Ave    Los Angeles
# 19          4538 E Cesar E Chavez Ave    Los Angeles
# 20                 3000 S Figueroa St    Los Angeles
# 21                       422 E 2nd St    Los Angeles
# 22            10250 Santa Monica Blvd    Los Angeles
# 23                 5300 Centinela Ave    Los Angeles
# 24                       347 E 2nd St    Los Angeles
# 25                     454 N Canon Dr  Beverly Hills
# 26          4533 E Cesar E Chavez Ave    Los Angeles
# 27                 5300 Centinela Ave    Los Angeles
# 28                5319-51 Sunset Blvd    Los Angeles
# 29          4629 E Cesar E Chavez Ave    Los Angeles
# 30          4629 E Cesar E Chavez Ave    Los Angeles
# 31                 5300 Centinela Ave    Los Angeles
# 32          4538 E Cesar E Chavez Ave    Los Angeles
# 33          4533 E Cesar E Chavez Ave    Los Angeles
# 34          4619 E Cesar E Chavez Ave    Los Angeles
# 35                  735 S Figueroa St    Los Angeles
# 36                       316 E 1st St    Los Angeles
# 37                 2801 Crenshaw Blvd    Los Angeles
# 38            10250 Santa Monica Blvd    Los Angeles
# 39                 1905 S Western Ave    Los Angeles
# 40                5900 Hollywood Blvd    Los Angeles
# 41               2080 S Atlantic Blvd  Monterey Park
# 42                 3335 S Figueroa St    Los Angeles
# 43                 3026 S Figueroa St    Los Angeles
# 44                 3993 S Western Ave    Los Angeles
# 45                       422 E 2nd St    Los Angeles
# 46                       347 E 2nd St    Los Angeles
# 47                      330 S Hope St    Los Angeles
# 48                5900 Hollywood Blvd    Los Angeles
# 49                5855 W Century Blvd    Los Angeles
#
#                               rtable_name rtable_category_1 rtable_category_2  \
# 0                       Alegria on Sunset           Mexican               NaN
# 1                            Natalee Thai             Asian              Thai
# 2                             La Parrilla           Mexican             Latin
# 3                             Smashburger          American         Fast Food
# 4                             Curry House             Asian          Japanese
# 5                                 Rubio's               NaN               NaN
# 6                           Panda Express           Chinese         Fast Food
# 7                        Raffallo's Pizza           Italian             Pizza
# 8                  Chipotle Mexican Grill           Mexican               NaN
# 9                                 Saffron            Indian               NaN
# 10                           Pizza Romana             Pizza           Italian
# 11                                Rubio's               NaN               NaN
# 12                              King Taco           Mexican             Latin
# 13                                Rubio's               NaN               NaN
# 14  Atlantic Seafood & Dim Sum restaurant           Chinese           Seafood
# 15                 Southern Girl Desserts               NaN               NaN
# 16                            Chick-fil-A         Fast Food          American
# 17                          El Pollo Loco           Mexican           Spanish
# 18                               Guisados           Mexican             Latin
# 19                               Guisados           Mexican             Latin
# 20                 Chipotle Mexican Grill           Mexican         Fast Food
# 21               Kula Revolving Sushi Bar          Japanese             Sushi
# 22                            Shake Shack          American         Fast Food
# 23                          El Pollo Loco           Mexican         Fast Food
# 24               Kula Revolving Sushi Bar          Japanese             Sushi
# 25                    Spago Beverly Hills           Italian          American
# 26                               Guisados           Mexican             Latin
# 27                          El Pollo Loco           Mexican         Fast Food
# 28                          El Pollo Loco           Mexican         Fast Food
# 29                            La Parrilla           Mexican             Latin
# 30                              King Taco           Mexican             Latin
# 31                          El Pollo Loco           Mexican         Fast Food
# 32                        Tamales Liliana           Mexican               NaN
# 33                        Tamales Liliana           Mexican               NaN
# 34                        Tamales Liliana           Mexican               NaN
# 35                   Built Custom Burgers          American         Fast Food
# 36                             Sushi Enya          Japanese             Sushi
# 37                          El Pollo Loco           Mexican         Fast Food
# 38                           Astro Burger          American         Fast Food
# 39                 Sorrento's Pizza House           Italian             Pizza
# 40                  Boran Thai Restaurant             Asian              Thai
# 41                             Duck House           Chinese             Asian
# 42                            Chick-fil-A         Fast Food          American
# 43                            Chick-fil-A         Fast Food          American
# 44                 Sorrento's Pizza House           Italian             Pizza
# 45                                 Komasa          Japanese             Sushi
# 46                                 Komasa          Japanese             Sushi
# 47               California Pizza Kitchen          American             Pizza
# 48              Hollywood Thai Restaurant             Asian              Thai
# 49                        JW's Steakhouse          American        Steakhouse
#
#                                rtable_address     rtable_city
# 0                          3510 W Sunset Blvd     Los Angeles
# 1                        998 S Robertson Blvd     Los Angeles
# 2                   2126 E Cesar E Chavez Ave     Los Angeles
# 3                          1011 S Figueroa St     Los Angeles
# 4                123 Astronaut E S Onizuka St     Los Angeles
# 5                            308 Westwood Plz     Los Angeles
# 6                          5543 W Sunset Blvd     Los Angeles
# 7                          1657 N La Brea Ave     Los Angeles
# 8                          5550 Wilshire Blvd     Los Angeles
# 9                             300 S Grand Ave     Los Angeles
# 10                          615 N La Brea Ave     Los Angeles
# 11                           308 Westwood Plz     Los Angeles
# 12                  2400 E Cesar E Chavez Ave     Los Angeles
# 13                           308 Westwood Plz     Los Angeles
# 14                        500 N Atlantic Blvd   Monterey Park
# 15  3650 W Martin Luther King Jr Blvd Ste 100     Los Angeles
# 16                         3758 S Figueroa St     Los Angeles
# 17                          503 S Alvarado St     Los Angeles
# 18                  2100 E Cesar E Chavez Ave     Los Angeles
# 19                  2100 E Cesar E Chavez Ave     Los Angeles
# 20                         3748 S Figueroa St     Los Angeles
# 21                               333 E 2nd St     Los Angeles
# 22                     8520 Santa Monica Blvd  West Hollywood
# 23                         8154 W Sunset Blvd     Los Angeles
# 24                               333 E 2nd St     Los Angeles
# 25                             176 N Canon Dr   Beverly Hills
# 26                  2100 E Cesar E Chavez Ave     Los Angeles
# 27                         7101 W Sunset Blvd     Los Angeles
# 28                     8239 Topanga Canyon Rd     Los Angeles
# 29                  2126 E Cesar E Chavez Ave     Los Angeles
# 30                  2400 E Cesar E Chavez Ave     Los Angeles
# 31                     8239 Topanga Canyon Rd     Los Angeles
# 32                  4629 E Cesar E Chavez Ave     Los Angeles
# 33                  4629 E Cesar E Chavez Ave     Los Angeles
# 34                  4629 E Cesar E Chavez Ave     Los Angeles
# 35                         3584 S Figueroa St     Los Angeles
# 36                               343 E 1st St     Los Angeles
# 37                     8239 Topanga Canyon Rd     Los Angeles
# 38                     7475 Santa Monica Blvd     Los Angeles
# 39                         2428 S Western Ave     Los Angeles
# 40                        5401 Hollywood Blvd     Los Angeles
# 41                        501 S Atlantic Blvd   Monterey Park
# 42                         3758 S Figueroa St     Los Angeles
# 43                         3758 S Figueroa St     Los Angeles
# 44                         2428 S Western Ave     Los Angeles
# 45                               351 E 2nd St     Los Angeles
# 46                               351 E 2nd St     Los Angeles
# 47                              330 S Hope St     Los Angeles
# 48                        5241 Hollywood Blvd     Los Angeles
# 49                        5855 W Century Blvd     Los Angeles

# %%
# save C
C.to_csv('../data/C.csv', index = False)

# %% [markdown]
# # Matching tuple pairs in the candidate set

# %% [markdown]
# ## Sampling the labeling the candidate set

# %% [markdown]
# First, randomly sample 500 tuple paris for labeling

# %%
# sample candidate set
S = em.sample_table(C, 500)

# save the sample table
S.to_csv('../data/S.csv', index = False)

# %%
# Load the labeled data
G = em.read_csv_metadata('../data/S_labeled.csv', key='_id', 
                         ltable=A, rtable=B, fk_ltable='ltable_id', fk_rtable='rtable_id')

print("Table G with length %d" % len(G))
G.head()
# Out:
# Table G with length 500
#    _id ltable_id rtable_id                          ltable_name  \
# 0    1        a1      b162  Hae Jang Chon Korean BBQ Restaurant
# 1   23        a2      b162               Kang Ho-dong Baekjeong
# 2   24        a2      b268               Kang Ho-dong Baekjeong
# 3   32        a2     b1987               Kang Ho-dong Baekjeong
# 4  177       a37      b162           Hangari Bajirak Kalgooksoo
#
#   ltable_address  ltable_city  ltable_zipcode  ltable_phone  \
# 0  3821 W 6th St  Los Angeles           90020  2.133899e+09
# 1  3465 W 6th St  Los Angeles           90020  2.133850e+09
# 2  3465 W 6th St  Los Angeles           90020  2.133850e+09
# 3  3465 W 6th St  Los Angeles           90020  2.133850e+09
# 4  3470 W 6th St  Los Angeles           90020  2.133882e+09
#
#                            rtable_name        rtable_address  rtable_city  \
# 0  Hae Jang Chon Korean BBQ Restaurant         3821 W 6th St  Los Angeles
# 1  Hae Jang Chon Korean BBQ Restaurant         3821 W 6th St  Los Angeles
# 2                Kang Hodong Baekjeong         3465 W 6th St  Los Angeles
# 3                KangHoDong Baek Jeong  3465 W 6th St Ste 20  Los Angeles
# 4  Hae Jang Chon Korean BBQ Restaurant         3821 W 6th St  Los Angeles
#
#    rtable_zipcode  rtable_phone  labe
# 0         90020.0  2.133899e+09     1
# 1         90020.0  2.133899e+09     0
# 2         90020.0  2.133850e+09     1
# 3         90020.0  2.133850e+09     1
# 4         90020.0  2.133899e+09     0

# %%
# Split G into I and J
IJ = em.split_train_test(G, train_proportion=0.5, random_state=0)
I = IJ['train']
J = IJ['test']
# Store I and J in csv format
em.to_csv_metadata(I, '../data/I.csv')
em.to_csv_metadata(J, '../data/J.csv')
print('length of I: %d' % len(I))
print('length of J: %d' % len(J))
# Out:
# length of I: 250
# length of J: 250

# %% [markdown]
# ## Creating  a set of learning-based matchers
#
# We created the following matchers: (1) decision tree, (2) random forest, (3) naive bayes, (4) svm, (5) logistic regression, and (6) linear regression.

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='NaiveBayes')

# %% [markdown]
# ## Creating features
#
# Next, we selected the attributes, including name, category_1, category_2, address, city, zipcodw and phone, in the input tables, and automatically generated features by py_entitymatching built-in function.

# %%
# Generate a set of features
F = em.get_features_for_matching(A.iloc[:, 1:8], B.iloc[:, 1:8], validate_inferred_attr_types=False)

# Show the generated features
print("Magellan generated the following %s features" % len(F))
F.feature_name
# Out:
# Magellan generated the following 48 features
# 0                     name_name_jac_qgm_3_qgm_3
# 1                 name_name_cos_dlm_dc0_dlm_dc0
# 2                 name_name_jac_dlm_dc0_dlm_dc0
# 3                                 name_name_mel
# 4                            name_name_lev_dist
# 5                             name_name_lev_sim
# 6                                 name_name_nmw
# 7                                  name_name_sw
# 8         category_1_category_1_jac_qgm_3_qgm_3
# 9     category_1_category_1_cos_dlm_dc0_dlm_dc0
# 10    category_1_category_1_jac_dlm_dc0_dlm_dc0
# 11                    category_1_category_1_mel
# 12               category_1_category_1_lev_dist
# 13                category_1_category_1_lev_sim
# 14                    category_1_category_1_nmw
# 15                     category_1_category_1_sw
# 16        category_2_category_2_jac_qgm_3_qgm_3
# 17    category_2_category_2_cos_dlm_dc0_dlm_dc0
# 18    category_2_category_2_jac_dlm_dc0_dlm_dc0
# 19                    category_2_category_2_mel
# 20               category_2_category_2_lev_dist
# 21                category_2_category_2_lev_sim
# 22                    category_2_category_2_nmw
# 23                     category_2_category_2_sw
# 24              address_address_jac_qgm_3_qgm_3
# 25          address_address_cos_dlm_dc0_dlm_dc0
# 26          address_address_jac_dlm_dc0_dlm_dc0
# 27                          address_address_mel
# 28                     address_address_lev_dist
# 29                      address_address_lev_sim
# 30                          address_address_nmw
# 31                           address_address_sw
# 32                    city_city_jac_qgm_3_qgm_3
# 33                city_city_cos_dlm_dc0_dlm_dc0
# 34                city_city_jac_dlm_dc0_dlm_dc0
# 35                                city_city_mel
# 36                           city_city_lev_dist
# 37                            city_city_lev_sim
# 38                                city_city_nmw
# 39                                 city_city_sw
# 40                          zipcode_zipcode_exm
# 41                          zipcode_zipcode_anm
# 42                     zipcode_zipcode_lev_dist
# 43                      zipcode_zipcode_lev_sim
# 44                              phone_phone_exm
# 45                              phone_phone_anm
# 46                         phone_phone_lev_dist
# 47                          phone_phone_lev_sim
# Name: feature_name, dtype: object

# %% [markdown]
# ## Extracting feature vectors
#
# We then extracted feature vectors using the development set (I) created features.

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=F, 
                            attrs_after='labe',
                            show_progress=False)
print('The table of feature vecors:')
H.head()
# Out:
# The table of feature vecors:
#         _id ltable_id rtable_id  name_name_jac_qgm_3_qgm_3  \
# 476  842418     a1853     b1255                   0.125000
# 162   36618     a1400     b2392                   1.000000
# 34     3380     a2092     b1024                   0.157895
# 44     5763       a53       b42                   1.000000
# 97    14717     a1050      b599                   0.090909
#
#      name_name_cos_dlm_dc0_dlm_dc0  name_name_jac_dlm_dc0_dlm_dc0  \
# 476                       0.353553                          0.200
# 162                       1.000000                          1.000
# 34                        0.333333                          0.200
# 44                        1.000000                          1.000
# 97                        0.235702                          0.125
#
#      name_name_mel  name_name_lev_dist  name_name_lev_sim  name_name_nmw  \
# 476       0.723671                18.0           0.217391           -9.0
# 162       1.000000                 0.0           1.000000            9.0
# 34        0.642839                13.0           0.409091            5.0
# 44        1.000000                 0.0           1.000000            5.0
# 97        0.410256                22.0           0.153846           -4.0
#
#      ...   city_city_sw  zipcode_zipcode_exm  zipcode_zipcode_anm  \
# 476  ...            1.0                  NaN                  NaN
# 162  ...           11.0                  1.0                  1.0
# 34   ...           11.0                  1.0                  1.0
# 44   ...           11.0                  1.0                  1.0
# 97   ...           11.0                  1.0                  1.0
#
#      zipcode_zipcode_lev_dist  zipcode_zipcode_lev_sim  phone_phone_exm  \
# 476                       NaN                      NaN              NaN
# 162                       0.0                      1.0              1.0
# 34                        0.0                      1.0              0.0
# 44                        0.0                      1.0              1.0
# 97                        0.0                      1.0              0.0
#
#      phone_phone_anm  phone_phone_lev_dist  phone_phone_lev_sim  labe
# 476              NaN                   NaN                  NaN     0
# 162         1.000000                   0.0             1.000000     1
# 34          0.999814                   5.0             0.583333     0
# 44          1.000000                   0.0             1.000000     1
# 97          1.000000                   5.0             0.583333     0
#
# [5 rows x 52 columns]

# %%
# Check if the feature vectors contain missing values
any(pd.notnull(H))
# Out:
# True

# %% [markdown]
# We observed that the extracted feature vectors contain missing values. Thus, We have to impute the missing values for the learning-based matchers to fit the model correctly. Here, we impute the missing value in a column with the mean of the values in that column.

# %%
# Impute feature vectors with the mean of the column values.
H = em.impute_table(H, 
                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'],
                strategy='mean')

# %% [markdown]
# ## Selecting the best matcher using cross-validation
#
# Now, we selected the best matcher using 5-fold cross-validation and used 'precision' metric to select the best matcher.

# %%
# Select the best ML matcher using CV
result = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'],
        k=5,
        target_attr='labe', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.946289        0.962761    0.953599
# 1            RF           0.969858        0.979259    0.974203
# 2           SVM           0.895076        0.942678    0.915440
# 3        LinReg           0.977000        0.971852    0.974205
# 4        LogReg           0.960386        0.949428    0.953793
# 5    NaiveBayes           0.985185        0.951852    0.966864

# %% [markdown]
# ## Debug matcher (Naive Bayes)
#
# In this step, we choosed the best matcher -- Naive Bayes -- based on precision score, and tested the extra feature related to price and rating.

# %%
# Split H into P and Q
PQ = em.split_train_test(H, train_proportion=0.5, random_state=0)
P = PQ['train']
Q = PQ['test']

# Create a feature on the value of (price + rating), then compute Levenshtein similarity
sim = em.get_sim_funs_for_matching()
tok = em.get_tokenizers_for_matching()
feature_string = """lev_sim(wspace(float(ltuple['price']) + float(ltuple['rating'])), 
                            wspace(float(rtuple['price']) + float(rtuple['rating'])))"""
feature = em.get_feature_fn(feature_string, sim, tok)

# Add feature to F
em.add_feature(F, 'lev_ws_price+rating', feature)
# Out:
# True

# %%
# Train using feature vectors from P
Pf = em.extract_feature_vecs(P, feature_table=F, attrs_after='labe',show_progress=False)
Pf = em.impute_table(Pf, 
                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'],
                strategy='mean')

# Train using feature vectors from P
matcher = nb
name = 'NaiveBayes'
matcher.fit(table=Pf, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
       target_attr='labe')

# Convert Q into a set of feature vectors using F
Qf = em.extract_feature_vecs(Q, feature_table=F, attrs_after=['labe'])
Qf = em.impute_table(Qf, 
                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'],
                strategy='mean')

# Predict
predictions = matcher.predict(table=Qf, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
              append=True, target_attr='predicted', inplace=False)

# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'labe', 'predicted')
print(name)
em.print_eval_summary(eval_result)
eval_summary = em.eval_matches(predictions, 'labe', 'predicted')
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# NaiveBayes
# Precision : 100.0% (58/58)
# Recall : 89.23% (58/65)
# F1 : 94.31%
# False positives : 0 (out of 58 positive predictions)
# False negatives : 7 (out of 67 negative predictions)

# %% [markdown]
# ## Selecting the best matcher again with the new feature set
# We observed that the new feature set with extra feature could improve the precision of Naive Bayes matcher.
# we then tested the new feature set on 6 matchers with cross validation.
# The best matcher is still the Naive Bayes matcher.

# %%
# Convert I into feature vectors using updated F
H = em.extract_feature_vecs(I, 
                            feature_table=F, 
                            attrs_after='labe',
                            show_progress=False)
H = em.impute_table(H, 
                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'],
                strategy='mean')

# Select the best matcher again using CV
result = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'],
        k=5,
        target_attr='labe', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.960696        0.962761    0.961258
# 1            RF           0.976623        0.963502    0.969706
# 2           SVM           0.893651        0.933587    0.910848
# 3        LinReg           0.977000        0.971852    0.974205
# 4        LogReg           0.960386        0.949428    0.953793
# 5    NaiveBayes           0.985185        0.951852    0.966864

# %% [markdown]
# ## Test the matchers on testing set (J)
#
# Next, we trained the 6 matchers with new feature vectors generated from set I and debugging step, and tested on set J.
# The following is the resuslt of each matcher:
#
#
# ### Decision Tree

# %%
# decision tree
matcher = dt
name = 'DecisionTree'

matcher.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
       target_attr='labe')

Ht = em.extract_feature_vecs(J, 
                            feature_table=F, 
                            attrs_after='labe',
                            show_progress=False)
Ht = em.impute_table(Ht, 
                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'],
                strategy='mean')

# Predict
predictions = matcher.predict(table=Ht, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
              append=True, target_attr='predicted', inplace=False)

# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'labe', 'predicted')
print(name)
em.print_eval_summary(eval_result)
eval_summary = em.eval_matches(predictions, 'labe', 'predicted')
# Out:
# DecisionTree
# Precision : 91.18% (124/136)
# Recall : 95.38% (124/130)
# F1 : 93.23%
# False positives : 12 (out of 136 positive predictions)
# False negatives : 6 (out of 114 negative predictions)

# %% [markdown]
# ### SVM

# %%
# SVM
matcher = svm
name = 'SVM'

matcher.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
       target_attr='labe')

# Predict
predictions = matcher.predict(table=Ht, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
              append=True, target_attr='predicted', inplace=False)

# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'labe', 'predicted')
print(name)
em.print_eval_summary(eval_result)
eval_summary = em.eval_matches(predictions, 'labe', 'predicted')
# Out:
# SVM
# Precision : 88.32% (121/137)
# Recall : 93.08% (121/130)
# F1 : 90.64%
# False positives : 16 (out of 137 positive predictions)
# False negatives : 9 (out of 113 negative predictions)

# %% [markdown]
# ### Random Forest

# %%
# Random Forest
matcher = rf
name = 'RandomForest'

matcher.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
       target_attr='labe')

# Predict
predictions = matcher.predict(table=Ht, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
              append=True, target_attr='predicted', inplace=False)

# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'labe', 'predicted')
print(name)
em.print_eval_summary(eval_result)
eval_summary = em.eval_matches(predictions, 'labe', 'predicted')
# Out:
# RandomForest
# Precision : 94.53% (121/128)
# Recall : 93.08% (121/130)
# F1 : 93.8%
# False positives : 7 (out of 128 positive predictions)
# False negatives : 9 (out of 122 negative predictions)

# %% [markdown]
# ### Naive Bayes

# %%
matcher = nb
name = 'NaiveBayes'

matcher.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
       target_attr='labe')

# Predict
predictions = matcher.predict(table=Ht, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
              append=True, target_attr='predicted', inplace=False)

# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'labe', 'predicted')
print(name)
em.print_eval_summary(eval_result)
eval_summary = em.eval_matches(predictions, 'labe', 'predicted')
# Out:
# NaiveBayes
# Precision : 97.6% (122/125)
# Recall : 93.85% (122/130)
# F1 : 95.69%
# False positives : 3 (out of 125 positive predictions)
# False negatives : 8 (out of 125 negative predictions)

# %% [markdown]
# ### Logistic Regression

# %%
matcher = lg
name = 'LogReg'

matcher.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
       target_attr='labe')

# Predict
predictions = matcher.predict(table=Ht, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
              append=True, target_attr='predicted', inplace=False)

# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'labe', 'predicted')
print(name)
em.print_eval_summary(eval_result)
eval_summary = em.eval_matches(predictions, 'labe', 'predicted')
# Out:
# LogReg
# Precision : 96.0% (120/125)
# Recall : 92.31% (120/130)
# F1 : 94.12%
# False positives : 5 (out of 125 positive predictions)
# False negatives : 10 (out of 125 negative predictions)

# %% [markdown]
# ### Linear Regression

# %%
matcher = ln
name = 'LinReg'

matcher.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
       target_attr='labe')

# Predict
predictions = matcher.predict(table=Ht, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'labe'], 
              append=True, target_attr='predicted', inplace=False)

# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'labe', 'predicted')
print(name)
em.print_eval_summary(eval_result)
eval_summary = em.eval_matches(predictions, 'labe', 'predicted')
# Out:
# LinReg
# Precision : 97.64% (124/127)
# Recall : 95.38% (124/130)
# F1 : 96.5%
# False positives : 3 (out of 127 positive predictions)
# False negatives : 6 (out of 123 negative predictions)

# %% [markdown]
# ## Test Results
#
# From the results above, we observed that the <b>Naive Bayes</b> (precision 97.6%) and the <b>Linear Regression</b> (precision 97.6%) have the best performance compared with precision score, while the <b>Linear Regression</b> matcher has the better recall and F1.
